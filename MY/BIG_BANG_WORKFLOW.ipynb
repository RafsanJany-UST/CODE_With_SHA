# %% [markdown]
# # <font color='#8B0000' size = 10> The Triassic Period</font>

# %%
import pandas as pd
import numpy as np

# Set random seed for reproducibility
np.random.seed(42)
n_samples = 200
subject_ids = [f'SUBJ_{i:04d}' for i in range(n_samples)]

# 1. Health Exam Dataset
health_exam = pd.DataFrame({
    'USUBJID': subject_ids,
    'SITEID': np.random.choice(['SITE_A', 'SITE_B', 'SITE_C'], size=n_samples),
    'BIRTHDTC': pd.to_datetime(np.random.choice(pd.date_range('1940-01-01', '1975-12-31'), size=n_samples)),
    'SEX': np.random.choice(['Male', 'Female'], size=n_samples),
    'MSYN': np.random.choice(['Yes', 'No'], size=n_samples),
    'HEIGHT': np.random.normal(165, 10, size=n_samples),
    'WEIGHT': np.random.normal(70, 15, size=n_samples),
    'BMI': np.random.normal(25, 4, size=n_samples),
    'SYSBP': np.random.normal(120, 15, size=n_samples),
    'DIABP': np.random.normal(80, 10, size=n_samples),
    'PULSE': np.random.normal(72, 8, size=n_samples),
    'SMOKECNF': np.random.choice(['Yes', 'No'], size=n_samples),
    'ALCOHOLYN': np.random.choice(['Yes', 'No'], size=n_samples),
    'MH_HL': np.random.choice(['Yes', 'No'], size=n_samples),
    'MH_HTN': np.random.choice(['Yes', 'No'], size=n_samples),
    'MH_DM': np.random.choice(['Yes', 'No'], size=n_samples),
    'CM_HL': np.random.choice(['Yes', 'No'], size=n_samples),
    'CM_HTN': np.random.choice(['Yes', 'No'], size=n_samples),
    'CM_DM': np.random.choice(['Yes', 'No'], size=n_samples),
    'cold': np.random.normal(5, 2, size=n_samples),
    'heat': np.random.normal(5, 2, size=n_samples),
    'chcat': np.random.choice(['Cold', 'Neutral', 'Hot'], size=n_samples),
    'PSSTOTAL': np.random.randint(0, 40, size=n_samples),
    'PSQITOTAL': np.random.randint(0, 20, size=n_samples),
    'CREAT': np.random.normal(1, 0.2, size=n_samples),
    'GFRE': np.random.normal(90, 15, size=n_samples),
    'HGB': np.random.normal(14, 1.5, size=n_samples),
    'GLUC': np.random.normal(100, 20, size=n_samples),
    'AST': np.random.normal(25, 5, size=n_samples),
    'ALT': np.random.normal(30, 7, size=n_samples),
    'GGT': np.random.normal(40, 10, size=n_samples),
    'WAISTCIR': np.random.normal(90, 10, size=n_samples),
    'HIPCIR': np.random.normal(100, 8, size=n_samples)
})

# 2. Bioimpedance Dataset
bioimpedance = pd.DataFrame({
    'USUBJID': subject_ids,
    'TBW': np.random.normal(42, 6, size=n_samples),
    'ICW': np.random.normal(28, 4, size=n_samples),
    'ECW': np.random.normal(14, 2, size=n_samples),
    'PROT': np.random.normal(12, 2, size=n_samples),
    'MINERAL': np.random.normal(4, 0.5, size=n_samples),
    'SLM': np.random.normal(40, 6, size=n_samples),
    'FFM': np.random.normal(55, 7, size=n_samples),
    'SMM': np.random.normal(30, 5, size=n_samples),
    'PBF': np.random.normal(25, 6, size=n_samples),
    'SLRA–SLLL': np.random.normal(12, 2, size=n_samples),
    'SWRA–SWLL': np.random.normal(22, 3, size=n_samples),
    'ICWRA–ICWLL': np.random.normal(15, 2.5, size=n_samples),
    'ECWRA–ECWLL': np.random.normal(7, 1.2, size=n_samples),
    'ECWR': np.random.normal(0.4, 0.05, size=n_samples),
    'ECWRRA–ECWRLL': np.random.normal(0.42, 0.03, size=n_samples),
    'FATRA–FATLL': np.random.normal(8, 1.5, size=n_samples),
    'BMR': np.random.normal(1500, 150, size=n_samples),
    'ABFR': np.random.normal(0.9, 0.1, size=n_samples),
    'VFA': np.random.normal(100, 20, size=n_samples),
    'BCM': np.random.normal(22, 3, size=n_samples),
    'BRMC': np.random.normal(21, 2.5, size=n_samples),
    'BMC': np.random.normal(3, 0.3, size=n_samples),
    'BHYDR': np.random.normal(0.55, 0.05, size=n_samples),
    'FFMI': np.random.normal(18, 2, size=n_samples),
    'FMI': np.random.normal(7, 1.5, size=n_samples),
    'CHMC': np.random.normal(10, 1.5, size=n_samples),
    'ABDMC': np.random.normal(12, 2, size=n_samples),
    'RAMC': np.random.normal(5, 0.8, size=n_samples),
    'LAMC': np.random.normal(5, 0.8, size=n_samples),
    'RLMC': np.random.normal(8, 1.2, size=n_samples),
    'LLMC': np.random.normal(8, 1.2, size=n_samples),
    'CHSTFATTHICK': np.random.normal(10, 2, size=n_samples),
    'ABDMFATTHICK': np.random.normal(12, 2, size=n_samples),
    'RAFATTHICK': np.random.normal(8, 1.5, size=n_samples),
    'LAFATTHICK': np.random.normal(8, 1.5, size=n_samples),
    'RLFATTHICK': np.random.normal(7, 1.5, size=n_samples),
    'LLFATTHICK': np.random.normal(7, 1.5, size=n_samples)
})

# 3. HRV Dataset
hrv_dataset = pd.DataFrame({
    'USUBJID': subject_ids,
    'DVDTC': pd.to_datetime(np.random.choice(pd.date_range('2022-01-01', '2024-12-31'), size=n_samples)),
    'VLF': np.random.normal(750, 150, size=n_samples),
    'LF': np.random.normal(550, 100, size=n_samples),
    'HF': np.random.normal(400, 90, size=n_samples),
    'TP': np.random.normal(1700, 250, size=n_samples),
    'LFNM': np.random.normal(0.4, 0.1, size=n_samples),
    'HFNM': np.random.normal(0.3, 0.1, size=n_samples),
    'HR': np.random.normal(70, 10, size=n_samples),
    'HRVINDEX': np.random.normal(15, 4, size=n_samples),
    'SDNN': np.random.normal(50, 10, size=n_samples)
})

# Save each dataset to separate Excel sheets
health_exam.to_excel("Health_Exam_Synthetic.xlsx", index=False)
bioimpedance.to_excel("Bioimpedance_Synthetic.xlsx", index=False)
hrv_dataset.to_excel("HRV_Synthetic.xlsx", index=False)
